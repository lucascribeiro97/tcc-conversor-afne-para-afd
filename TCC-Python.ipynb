# %%
pip install automata-lib pandas graphviz colormath pip install jupyterlab visual-automata
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# # ***Importação das classes***

# %%
from automata.fa.nfa import NFA 
from visual_automata.fa.nfa import VisualNFA 
from automata.fa.dfa import DFA 
from visual_automata.fa.dfa import VisualDFA

# %% [markdown]
# # ***EXEMPLO 1***

# %% [markdown]
# # ***AFNe (Autômato finito não determinístico com movimentos vazios)***

# %%
afne1 = VisualNFA(
    states={"q0", "qf"}, #Estados da máquina
    input_symbols={"a", "b"}, #Símbolos que serão manipulados
    transitions={
        "q0": {"a": {"q0"}, "": {"qf"}},
        "qf": {"b": {"qf"}},
    }, #Transições
    initial_state="q0", #Estado inicial
    final_states={"qf"},#Estado final
)

# %%
#Gerar tabela de transições do AFNe
afne1.table
# Out:
#       a    b    λ
# →q0  q0    ∅  *qf
# *qf   ∅  *qf    ∅

# %%
# Gerar diagrama ANFe
afne1.show_diagram()

# %%
#Executar a palavra "aabb" no diagrama AFN
afne1.show_diagram ("aabb")
# Out:
#           [Accepted]
# Step: Current state: Input symbol: New state:
# 1                →q0             a        →q0
# 2                →q0             a        *qf
# 3                *qf             b        *qf
# 4                *qf             b        *qf

# %%
#Executar a palavra "aabba" no diagrama AFN
afne1.show_diagram ("aabba")
# Out:
#           [Rejected]
# Step: Current state: Input symbol: New state:
# 1                →q0             a        →q0
# 2                →q0             a        →q0
# 3                →q0             b          ∅

# %% [markdown]
# # ***AFN (Autômato finito não determinístico)***

# %%
#Eliminar transições vazias / Gerar AFN
afn1 = VisualNFA.eliminate_lambda(afne1)

# %%
#Gerar tabela de transições do AFN
afn1.table
# Out:
#             a    b
# →q0  {q0,*qf}  *qf
# *qf         ∅  *qf

# %%
#Gerar diagrama AFN
afn1.show_diagram()

# %%
#Executar a palavra "aabb" no diagrama AFN
afn1.show_diagram ("aabb")
# Out:
#           [Accepted]
# Step: Current state: Input symbol: New state:
# 1                →q0             a        →q0
# 2                →q0             a        →q0
# 3                →q0             b        *qf
# 4                *qf             b        *qf

# %%
#Executar a palavra "aabba" no diagrama AFN
afn1.show_diagram ("aabba")
# Out:
#           [Rejected]
# Step: Current state: Input symbol: New state:
# 1                →q0             a        *qf
# 2                *qf             a          ∅

# %% [markdown]
# # ***AFD (Autômato finito determinístico)***

# %%
#Gerar AFD automata-lib a partir do AFN
afd1 = DFA.from_nfa(afn1)

# %%
#Converter AFD automata-lib em AFD Visual Automata
afd1 = VisualDFA(afd1)

# %%
#Gerar tabela de transições do AFD
afd1.table
# Out:
#                  a      b
# {}              {}     {}
# →{q0}     *{q0,qf}  *{qf}
# *{q0,qf}  *{q0,qf}  *{qf}
# *{qf}           {}  *{qf}

# %%
#Gerar diagrama AFD
afd1.show_diagram()

# %%
#Executar a palavra "aabb" no diagrama AFD
afd1.show_diagram("aabb")
# Out:
#           [Accepted]
# Step: Current state: Input symbol: New state:
# 1              →{q0}             a   *{q0,qf}
# 2           *{q0,qf}             a   *{q0,qf}
# 3           *{q0,qf}             b      *{qf}
# 4              *{qf}             b      *{qf}

# %%
#Executar a palavra "aabba" no diagrama AFD
afd1.show_diagram("aabba")
# Out:
#           [Rejected]
# Step: Current state: Input symbol: New state:
# 1              →{q0}             a   *{q0,qf}
# 2           *{q0,qf}             a   *{q0,qf}
# 3           *{q0,qf}             b      *{qf}
# 4              *{qf}             b      *{qf}
# 5              *{qf}             a         {}

# %% [markdown]
# # ***Exemplo 2***

# %% [markdown]
# # ***AFNe (Autômato finito não determinístico com movimentos vazios)***

# %%
afne2 = VisualNFA(
states={"q0", "q1", "q2"}, #Estados da máquina
input_symbols={"a", "b"}, #Símbolos que serão manipulados
transitions={
"q0": {"a": {"q0"}, "": {"q1"}},
"q1": {"b": {"q1"}, "": {"q2"}},
"q2": {"a": {"q2"}},
}, #Transições
initial_state="q0", #Estado inicial
final_states={"q2"}, #Estado final
)

# %%
#Gerar tabela de transições do AFNe
afne2.table
# Out:
#        a   b    λ
# →q0   q0   ∅   q1
# q1     ∅  q1  *q2
# *q2  *q2   ∅    ∅

# %%
# Gerar diagrama ANFe
afne2.show_diagram()

# %%
#Executar a palavra "aabb" no diagrama AFN
afne2.show_diagram ("aabb")
# Out:
#           [Accepted]
# Step: Current state: Input symbol: New state:
# 1                →q0             a        →q0
# 2                →q0             a         q1
# 3                 q1             b         q1
# 4                 q1             b        *q2

# %%
#Executar a palavra "aabbab" no diagrama AFN
afne2.show_diagram ("aabbab")
# Out:
#           [Rejected]
# Step: Current state: Input symbol: New state:
# 1                →q0             a        *q2
# 2                *q2             a        *q2
# 3                *q2             b          ∅

# %% [markdown]
# # ***AFN (Autômato finito não determinístico)***

# %%
#Eliminar transições vazias / Gerar AFN
afn2 = VisualNFA.eliminate_lambda(afne2)

# %%
#Gerar tabela de transições do AFN
afn2.table
# Out:
#                a         b
# →q0  {q0,q1,*q2}  {q1,*q2}
# q1           *q2  {q1,*q2}
# *q2          *q2         ∅

# %%
#Gerar diagrama AFN
afn2.show_diagram()

# %%
#Executar a palavra "aabb" no diagrama AFN
afn2.show_diagram ("aabb")
# Out:
#           [Accepted]
# Step: Current state: Input symbol: New state:
# 1                →q0             a        →q0
# 2                →q0             a        →q0
# 3                →q0             b         q1
# 4                 q1             b        *q2

# %%
#Executar a palavra "aabbab" no diagrama AFN
afn2.show_diagram ("aabbab")
# Out:
#           [Rejected]
# Step: Current state: Input symbol: New state:
# 1                →q0             a         q1
# 2                 q1             a        *q2
# 3                *q2             b          ∅

# %% [markdown]
# # ***AFD (Autômato finito determinístico)***

# %%
#Gerar AFD automata-lib a partir do AFN
afd2 = DFA.from_nfa(afn2)

# %%
#Converter AFD automata-lib em AFD Visual Automata
afd2 = VisualDFA(afd2)

# %%
#Gerar tabela de transições do AFD
afd2.table
# Out:
#                        a         b
# {}                    {}        {}
# →{q0}        *{q0,q1,q2}  *{q1,q2}
# *{q0,q1,q2}  *{q0,q1,q2}  *{q1,q2}
# *{q1,q2}           *{q2}  *{q1,q2}
# *{q2}              *{q2}        {}

# %%
#Gerar diagrama AFD
afd2.show_diagram()

# %%
#Executar a palavra "aabb" no diagrama AFD
afd2.show_diagram("aabb")
# Out:
#           [Accepted]
# Step: Current state: Input symbol:   New state:
# 1              →{q0}             a  *{q0,q1,q2}
# 2        *{q0,q1,q2}             a  *{q0,q1,q2}
# 3        *{q0,q1,q2}             b     *{q1,q2}
# 4           *{q1,q2}             b     *{q1,q2}

# %%
#Executar a palavra "aabbab" no diagrama AFD
afd2.show_diagram("aabbab")
# Out:
#           [Rejected]
# Step: Current state: Input symbol:   New state:
# 1              →{q0}             a  *{q0,q1,q2}
# 2        *{q0,q1,q2}             a  *{q0,q1,q2}
# 3        *{q0,q1,q2}             b     *{q1,q2}
# 4           *{q1,q2}             b     *{q1,q2}
# 5           *{q1,q2}             a        *{q2}
# 6              *{q2}             b           {}

# %% [markdown]
# # ***Exemplo 3***

# %% [markdown]
# # ***AFNe (Autômato finito não determinístico com movimentos vazios)***

# %%
afne3 = VisualNFA(
states={"q0", "q1", "q2", "q3"}, #Estados da máquina
input_symbols={"0", "1"}, #Símbolos que serão manipulados
transitions={
"q0": {"0": {"q1"}},
"q1": {"1": {"q2"}},
"q2": {"": {"q3"}},
"q3": {"": {"q0"}},
}, #Transições
initial_state="q0", #Estado inicial
final_states={"q3"}, #Estado final
)

# %%
#Gerar tabela de transições do AFNe
afne3.table
# Out:
#       0   1    λ
# →q0  q1   ∅    ∅
# q1    ∅  q2    ∅
# q2    ∅   ∅  *q3
# *q3   ∅   ∅   q0

# %%
# Gerar diagrama ANFe
afne3.show_diagram()

# %%
#Executar a palavra "01010101" no diagrama AFNe
afne3.show_diagram ("01010101")
# Out:
#           [Accepted]
# Step: Current state: Input symbol: New state:
# 1                →q0             0         q1
# 2                 q1             1        →q0
# 3                →q0             0         q1
# 4                 q1             1        →q0
# 5                →q0             0         q1
# 6                 q1             1        →q0
# 7                →q0             0         q1
# 8                 q1             1        *q3

# %%
#Executar a palavra "01110101" no diagrama AFNe
afne3.show_diagram ("01110101")
# Out:
#           [Rejected]
# Step: Current state: Input symbol: New state:
# 1                →q0             0         q1
# 2                 q1             1         q2
# 3                 q2             1          ∅

# %% [markdown]
# # ***AFN (Autômato finito não determinístico)***

# %%
#Eliminar transições vazias / Gerar AFN
afn3 = VisualNFA.eliminate_lambda(afne3)

# %%
#Gerar tabela de transições do AFN
afn3.table
# Out:
#       0            1
# →q0  q1            ∅
# q1    ∅  {q0,q2,*q3}
# q2   q1            ∅
# *q3  q1            ∅

# %%
#Gerar diagrama AFN
afn3.show_diagram()

# %%
#Executar a palavra "01010101" no diagrama AFN
afn3.show_diagram ("01010101")
# Out:
#           [Accepted]
# Step: Current state: Input symbol: New state:
# 1                →q0             0         q1
# 2                 q1             1         q2
# 3                 q2             0         q1
# 4                 q1             1         q2
# 5                 q2             0         q1
# 6                 q1             1         q2
# 7                 q2             0         q1
# 8                 q1             1        *q3

# %%
#Executar a palavra "01110101" no diagrama AFN
afn3.show_diagram ("01110101")
# Out:
#           [Rejected]
# Step: Current state: Input symbol: New state:
# 1                →q0             0         q1
# 2                 q1             1         q2
# 3                 q2             1          ∅

# %% [markdown]
# # ***AFD (Autômato finito determinístico)***

# %%
#Gerar AFD automata-lib a partir do AFN
afd3 = DFA.from_nfa(afn3)

# %%
#Converter AFD automata-lib em AFD Visual Automata
afd3 = VisualDFA(afd3)

# %%
#Gerar tabela de transições do AFD
afd3.table
# Out:
#                 0            1
# {}             {}           {}
# →{q0}        {q1}           {}
# *{q0,q2,q3}  {q1}           {}
# {q1}           {}  *{q0,q2,q3}

# %%
#Gerar diagrama AFD
afd3.show_diagram()

# %%
#Executar a palavra "01010101" no diagrama AFD
afd3.show_diagram("01010101")
# Out:
#           [Accepted]
# Step: Current state: Input symbol:   New state:
# 1              →{q0}             0         {q1}
# 2               {q1}             1  *{q0,q2,q3}
# 3        *{q0,q2,q3}             0         {q1}
# 4               {q1}             1  *{q0,q2,q3}
# 5        *{q0,q2,q3}             0         {q1}
# 6               {q1}             1  *{q0,q2,q3}
# 7        *{q0,q2,q3}             0         {q1}
# 8               {q1}             1  *{q0,q2,q3}

# %%
#Executar a palavra "01110101" no diagrama AFD
afd3.show_diagram("01110101")
# Out:
#           [Rejected]
# Step: Current state: Input symbol:   New state:
# 1              →{q0}             0         {q1}
# 2               {q1}             1  *{q0,q2,q3}
# 3        *{q0,q2,q3}             1           {}
# 4                 {}             1           {}
# 5                 {}             0           {}
# 6                 {}             1           {}
# 7                 {}             0           {}
# 8                 {}             1           {}
